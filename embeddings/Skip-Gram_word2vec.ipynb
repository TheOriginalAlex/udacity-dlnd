# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:12, 2.43MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''

    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    end = idx + R
    target_words = set(words[start:idx] + words[idx+1:end+1])

    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6366 0.0312 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6243 0.0291 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4790 0.0290 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5860 0.0291 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5099 0.0291 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5094 0.0289 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5807 0.0290 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5330 0.0290 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4803 0.0290 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4442 0.0289 sec/batch
# Nearest to used: maneaba, hashshashin, pleadings, saimaa, statisticians, unjustly, pharmaceuticals, firework,
# Nearest to known: vom, lfr, emporia, success, sh, chip, foam, chaitin,
# Nearest to united: stresses, humpback, malpractice, logs, kearns, indistinguishable, kramer, insured,
# Nearest to into: emory, encodes, barbecued, raucous, revels, daewoo, goku, exorcism,
# Nearest to state: mottled, beauties, rosslyn, lichens, persuasion, volgograd, rshavn, injected,
# Nearest to there: proviso, castletown, insulins, suggs, motionless, fluorescence, revolting, vaucher,
# Nearest to where: imposter, satchmo, generalisation, fraudulently, gbagbo, herbal, quests, pensacola,
# Nearest to been: excerpt, rebranding, excretory, hartenstein, handbuch, cilicia, polyploid, chandeliers,
# Nearest to http: pictorial, yauch, criticising, obscured, zwolle, eysteinn, creasy, reassessed,
# Nearest to orthodox: alberta, barringer, tailor, erode, cryptids, hagerstown, arianna, spurling,
# Nearest to consists: discovered, beckford, sulfate, smtp, clinical, muezzin, passive, fetched,
# Nearest to resources: cheesemaking, fauvism, trinidad, lenders, recalling, configurable, calculi, obelisk,
# Nearest to operations: elk, electroconvulsive, lingual, forts, fertilizers, crust, notional, gamow,
# Nearest to account: madrigals, vicarage, retrieve, appleseed, charged, plazas, spheroidal, toilet,
# Nearest to pope: tok, jitterbug, coloureds, memoirs, pure, unrest, catapulted, magdalene,
# Nearest to nobel: aldous, shouts, disputation, lavish, fretboard, carlsbad, lamar, mendeleev,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4858 0.0302 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3967 0.0292 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3529 0.0292 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2457 0.0289 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1685 0.0290 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1584 0.0290 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1642 0.0290 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0657 0.0289 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0368 0.0290 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0005 0.0292 sec/batch
# Nearest to used: center, international, we, pharmaceuticals, summer, unjustly, however, theodoric,
# Nearest to known: success, vom, adopt, chip, sh, emporia, occurring, embark,
# Nearest to united: stresses, evolving, humpback, traditions, therefore, allowed, documentary, fiction,
# Nearest to into: emory, organization, purposes, iie, optical, subscription, stronger, circuses,
# Nearest to state: during, mottled, persuasion, injected, weekly, musical, wiring, lack,
# Nearest to there: entitled, black, midnight, machines, vaucher, fluorescence, revolting, robert,
# Nearest to where: trouble, architect, confederation, cede, imposter, preferably, herbal, quests,
# Nearest to been: excerpt, changed, make, always, bought, excretory, strategy, rebranding,
# Nearest to http: pictorial, obscured, essentially, existence, accordingly, yauch, personal, criticising,
# Nearest to orthodox: alberta, tailor, barringer, erode, ietf, spurling, cryptids, hagerstown,
# Nearest to consists: discovered, capable, clinical, sulfate, usage, muezzin, deference, standpoint,
# Nearest to resources: trinidad, consistently, lenders, were, importance, cheesemaking, penetrated, contested,
# Nearest to operations: fertilizers, crust, elk, comparable, forts, vintage, mound, vistula,
# Nearest to account: madrigals, charged, wise, conventional, steps, elevator, retrieve, respective,
# Nearest to pope: tok, jitterbug, pure, memoirs, coloureds, unrest, totowa, temporary,
# Nearest to nobel: aldous, disputation, mendeleev, lavish, shouts, carlsbad, highways, prohibition,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9110 0.0304 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9077 0.0293 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8539 0.0291 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8664 0.0290 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8114 0.0289 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8092 0.0291 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7812 0.0290 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8097 0.0290 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7920 0.0291 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7954 0.0291 sec/batch
# Nearest to used: unjustly, we, pharmaceuticals, taboos, whaling, however, conformed, summer,
# Nearest to known: success, vom, sh, chip, adopt, deceived, foam, emporia,
# Nearest to united: stresses, church, evolving, centers, indistinguishable, logs, mining, generations,
# Nearest to into: emory, optical, happen, organization, purposes, subscription, customs, iie,
# Nearest to state: during, mottled, weekly, dissolution, shortage, beauties, injected, persuasion,
# Nearest to there: entitled, midnight, fluorescence, grigori, vaucher, suggs, black, proviso,
# Nearest to where: trouble, adjustment, imposter, architect, preferably, herbal, confederation, cede,
# Nearest to been: excerpt, changed, make, rebranding, indicative, bought, always, strategy,
# Nearest to http: pictorial, obscured, essentially, ccd, creasy, accordingly, existence, selecting,
# Nearest to orthodox: tailor, ietf, alberta, erode, barringer, palatinate, spurling, habsburgs,
# Nearest to consists: discovered, capable, clinical, sulfate, passive, standpoint, isomorphism, beckford,
# Nearest to resources: trinidad, philosophers, consistently, lenders, recalling, penetrated, stained, configurable,
# Nearest to operations: elk, crust, forts, comparable, vistula, vintage, fertilizers, noncommercial,
# Nearest to account: madrigals, charged, retrieve, hole, toilet, conventional, steps, housing,
# Nearest to pope: unrest, tok, memoirs, stalinism, pure, jitterbug, coloureds, magdalene,
# Nearest to nobel: aldous, disputation, lavish, mendeleev, shouts, pioneers, fretboard, highways,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7603 0.0301 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7641 0.0291 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7198 0.0291 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7007 0.0289 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7521 0.0291 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6921 0.0291 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7054 0.0290 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7220 0.0290 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7397 0.0290 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6625 0.0289 sec/batch
# Nearest to used: unjustly, taboos, we, conformed, whaling, however, ribonucleic, impotence,
# Nearest to known: success, sh, vom, chip, emporia, radiocommunication, foam, multivariate,
# Nearest to united: church, stresses, singapore, kramer, centers, consolidated, traditions, magnetically,
# Nearest to into: emory, happen, encodes, barbecued, customs, optical, organization, trojan,
# Nearest to state: during, dissolution, beauties, weekly, rosslyn, mottled, shortage, disrepair,
# Nearest to there: proviso, insulins, fluorescence, grigori, midnight, entitled, vaucher, libraries,
# Nearest to where: imposter, adjustment, herbal, trouble, fraudulently, quests, preferably, influencing,
# Nearest to been: excerpt, rebranding, make, cilicia, bought, chandeliers, conqueror, cleric,
# Nearest to http: pictorial, obscured, ccd, creasy, essentially, laotians, eysteinn, selecting,
# Nearest to orthodox: tailor, erode, alberta, ietf, spurling, barringer, cryptids, shipowners,
# Nearest to consists: clinical, discovered, sulfate, capable, isomorphism, muezzin, prevail, deference,
# Nearest to resources: trinidad, philosophers, lenders, cheesemaking, configurable, stained, rosicrucians, fauvism,
# Nearest to operations: elk, crust, electroconvulsive, forts, koran, vintage, comparable, vistula,
# Nearest to account: retrieve, toilet, charged, madrigals, vicarage, hole, appleseed, conventional,
# Nearest to pope: stalinism, memoirs, unrest, tok, magdalene, lan, coloureds, jitterbug,
# Nearest to nobel: aldous, disputation, mendeleev, pioneers, lavish, anatomist, austrian, slovakia,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6865 0.0301 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6717 0.0290 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6201 0.0289 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6273 0.0291 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6510 0.0290 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6508 0.0289 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5948 0.0217 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5383 0.0289 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4737 0.0289 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5260 0.0289 sec/batch
# Nearest to used: unjustly, taboos, we, component, freezing, impotence, reverse, connect,
# Nearest to known: sh, success, emporia, vom, chip, multivariate, foam, radiocommunication,
# Nearest to united: singapore, church, kramer, magnetically, stresses, qatar, provisional, centers,
# Nearest to into: emory, encodes, selfish, daewoo, optical, happen, barbecued, mic,
# Nearest to state: rosslyn, weekly, dissolution, mottled, beauties, during, maine, shortage,
# Nearest to there: proviso, fluorescence, insulins, grigori, suggs, castletown, libraries, midnight,
# Nearest to where: herbal, imposter, trouble, adjustment, fraudulently, quests, preferably, pensacola,
# Nearest to been: make, excerpt, rebranding, cilicia, chandeliers, cleric, bought, conqueror,
# Nearest to http: www, pictorial, obscured, ccd, creasy, laotians, hex, brotherhoods,
# Nearest to orthodox: tailor, alberta, erode, spurling, cryptids, religions, barringer, philanthropic,
# Nearest to consists: clinical, sulfate, discovered, capable, muezzin, isomorphism, prevail, beckford,
# Nearest to resources: trinidad, lenders, philosophers, cheesemaking, liv, stained, consistently, configurable,
# Nearest to operations: elk, crust, electroconvulsive, degenerative, vintage, koran, comparable, vistula,
# Nearest to account: retrieve, toilet, charged, vicarage, plazas, madrigals, appleseed, odie,
# Nearest to pope: memoirs, stalinism, unrest, tok, magdalene, lan, enclave, democrat,
# Nearest to nobel: austrian, prize, aldous, theologian, writer, b, athlete, anatomist,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4859 0.0300 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5298 0.0290 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4445 0.0293 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5205 0.0295 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4661 0.0290 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4819 0.0290 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4539 0.0290 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3863 0.0290 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4554 0.0290 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4368 0.0289 sec/batch
# Nearest to used: unjustly, encodes, use, atonal, pharmaceuticals, unproven, taboos, reverse,
# Nearest to known: sh, emporia, vom, success, foam, multivariate, chip, mannerisms,
# Nearest to united: singapore, qatar, centers, consolidated, magnetically, provisional, stresses, malpractice,
# Nearest to into: encodes, selfish, barbecued, optical, daewoo, emory, happen, mic,
# Nearest to state: dissolution, beauties, rosslyn, maine, during, mottled, weekly, disrepair,
# Nearest to there: proviso, fluorescence, libraries, castletown, insulins, relating, a, panhandle,
# Nearest to where: herbal, imposter, fraudulently, trouble, quests, bandanese, wuhan, bachman,
# Nearest to been: rebranding, make, cilicia, pyramids, bought, closed, polyploid, chandeliers,
# Nearest to http: www, creasy, pictorial, ccd, obscured, edu, laotians, hex,
# Nearest to orthodox: religions, tailor, spurling, alberta, cryptids, erode, succession, philanthropic,
# Nearest to consists: clinical, sulfate, discovered, attainment, capable, attached, passive, prevail,
# Nearest to resources: trinidad, lenders, reine, cheesemaking, colossus, improvements, statistically, configurable,
# Nearest to operations: elk, electroconvulsive, comparable, crust, koran, degenerative, vintage, vistula,
# Nearest to account: toilet, retrieve, vicarage, plazas, appleseed, charged, madrigals, creaky,
# Nearest to pope: stalinism, memoirs, unrest, tok, enclave, magdalene, saint, lan,
# Nearest to nobel: austrian, aldous, prize, writer, athlete, theologian, disputation, anatomist,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4126 0.0301 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4078 0.0290 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4221 0.0290 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4227 0.0290 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4113 0.0290 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4719 0.0290 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3668 0.0290 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3748 0.0290 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4074 0.0289 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3844 0.0290 sec/batch
# Nearest to used: unjustly, derivation, atonal, amplification, pharmaceuticals, encodes, unproven, use,
# Nearest to known: sh, emporia, vom, foam, success, multivariate, chip, lfr,
# Nearest to united: singapore, qatar, provisional, consolidated, maintains, centers, dudayev, malpractice,
# Nearest to into: encodes, daewoo, exuberance, selfish, emory, barbecued, mic, optical,
# Nearest to state: rosslyn, dissolution, beauties, mottled, disrepair, maine, membership, during,
# Nearest to there: proviso, fluorescence, castletown, libraries, panhandle, insulins, relating, a,
# Nearest to where: herbal, imposter, laplacian, preferably, solvable, fraudulently, bachman, wuhan,
# Nearest to been: rebranding, make, closed, pyramids, cilicia, polyploid, hartenstein, empiricists,
# Nearest to http: www, edu, creasy, ccd, pictorial, hex, obscured, laotians,
# Nearest to orthodox: religions, churches, succession, church, cryptids, alberta, spurling, coptic,
# Nearest to consists: clinical, sulfate, attainment, capable, passive, discovered, prevail, attached,
# Nearest to resources: trinidad, improvements, lenders, configurable, irrigated, level, cheesemaking, liv,
# Nearest to operations: elk, electroconvulsive, cinematographers, koran, crust, forts, inflation, comparable,
# Nearest to account: toilet, charged, retrieve, vicarage, appleseed, creaky, plazas, madrigals,
# Nearest to pope: stalinism, memoirs, unrest, tok, confessing, saint, enclave, magdalene,
# Nearest to nobel: austrian, aldous, prize, pioneers, theologian, athlete, writer, anatomist,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3869 0.0299 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4194 0.0290 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3700 0.0291 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3468 0.0290 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4038 0.0289 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3652 0.0292 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3763 0.0290 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3557 0.0289 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3230 0.0290 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3682 0.0289 sec/batch
# Nearest to used: unjustly, pharmaceuticals, amplification, atonal, hartnett, encodes, unproven, use,
# Nearest to known: sh, emporia, foam, vom, spelled, success, multivariate, taxis,
# Nearest to united: singapore, maintains, qatar, provisional, consolidated, stresses, magnetically, centers,
# Nearest to into: encodes, selfish, daewoo, emory, exuberance, customs, optical, goku,
# Nearest to state: rosslyn, dissolution, membership, beauties, disrepair, mottled, maine, resumption,
# Nearest to there: proviso, fluorescence, panhandle, relating, zarqawi, castletown, conn, motionless,
# Nearest to where: imposter, laplacian, herbal, solvable, wuhan, pensacola, bachman, impossibility,
# Nearest to been: rebranding, make, cilicia, closed, cleric, polyploid, conqueror, hartenstein,
# Nearest to http: www, edu, ccd, creasy, pictorial, hex, obscured, laotians,
# Nearest to orthodox: succession, religions, churches, church, cryptids, doctrine, spurling, coptic,
# Nearest to consists: sulfate, clinical, attainment, prevail, deference, averages, muezzin, congruent,
# Nearest to resources: trinidad, improvements, irrigated, level, configurable, lenders, natural, consistently,
# Nearest to operations: elk, electroconvulsive, cinematographers, forts, comparable, transmitter, degenerative, inflation,
# Nearest to account: toilet, appleseed, charged, retrieve, vicarage, plazas, odie, creaky,
# Nearest to pope: stalinism, memoirs, enclave, constantine, confessing, saint, magdalene, unrest,
# Nearest to nobel: aldous, prize, austrian, pioneers, disputation, theologian, lavish, mendeleev,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3551 0.0299 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2991 0.0290 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3770 0.0290 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3753 0.0288 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3514 0.0290 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2516 0.0291 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3178 0.0290 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3412 0.0290 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2236 0.0290 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3075 0.0289 sec/batch
# Nearest to used: unjustly, pharmaceuticals, amplification, encodes, atonal, derivation, vowel, hartnett,
# Nearest to known: sh, emporia, foam, spelled, rotuma, vom, lfr, finitely,
# Nearest to united: maintains, singapore, qatar, provisional, malpractice, magnetically, dudayev, needs,
# Nearest to into: encodes, daewoo, emory, goku, exuberance, upshot, selfish, mic,
# Nearest to state: rosslyn, dissolution, maine, resumption, membership, beauties, cumann, shortage,
# Nearest to there: proviso, castletown, relating, zarqawi, panhandle, fluorescence, mallorca, sidetracked,
# Nearest to where: imposter, laplacian, pensacola, herbal, wuhan, solvable, niggle, bachman,
# Nearest to been: rebranding, make, cilicia, hartenstein, cleric, polyploid, closed, conqueror,
# Nearest to http: www, edu, html, pictorial, ccd, creasy, hex, laotians,
# Nearest to orthodox: succession, cryptids, churches, religions, church, spurling, tailor, alberta,
# Nearest to consists: sulfate, clinical, attainment, muezzin, prevail, attached, congruent, deference,
# Nearest to resources: trinidad, natural, irrigated, improvements, lenders, escalators, conservation, consistently,
# Nearest to operations: elk, electroconvulsive, cinematographers, forts, sacagawea, vintage, comparable, inflation,
# Nearest to account: appleseed, toilet, charged, plazas, apollon, vicarage, retrieve, odie,
# Nearest to pope: stalinism, memoirs, constantine, saint, magdalene, invaded, enclave, confessing,
# Nearest to nobel: austrian, prize, aldous, physiology, theologian, pioneers, writer, anatomist,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3178 0.0300 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2739 0.0289 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3619 0.0141 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2419 0.0293 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2169 0.0292 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2324 0.0291 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2090 0.0292 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2278 0.0289 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2184 0.0289 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1826 0.0289 sec/batch
# Nearest to used: pharmaceuticals, encodes, atonal, amplification, unjustly, vowel, use, detailed,
# Nearest to known: sh, emporia, spelled, foam, rotuma, vom, fry, embark,
# Nearest to united: singapore, qatar, maintains, provisional, malpractice, u, kearns, magnetically,
# Nearest to into: encodes, daewoo, exuberance, goku, emory, selfish, upshot, mic,
# Nearest to state: rosslyn, dissolution, maine, beauties, membership, disrepair, cumann, resumption,
# Nearest to there: proviso, castletown, relating, fluorescence, or, motionless, zarqawi, furthermore,
# Nearest to where: laplacian, wuhan, imposter, pensacola, impossibility, bachman, inhabitants, complicates,
# Nearest to been: rebranding, cilicia, make, cleric, hartenstein, polyploid, conqueror, closed,
# Nearest to http: www, edu, html, pictorial, htm, ccd, hex, creasy,
# Nearest to orthodox: succession, church, religions, cryptids, churches, alberta, spurling, tailor,
# Nearest to consists: clinical, sulfate, attainment, congruent, prevail, statutes, muezzin, attached,
# Nearest to resources: trinidad, natural, irrigated, improvements, conservation, lenders, escalators, consistently,
# Nearest to operations: elk, electroconvulsive, cinematographers, forts, operational, transmitter, inflation, requested,
# Nearest to account: appleseed, toilet, spirit, creaky, odie, vicarage, apollon, charged,
# Nearest to pope: stalinism, constantine, memoirs, confessing, brotherhoods, prelates, magdalene, saint,
# Nearest to nobel: prize, aldous, austrian, pioneers, physiology, humanitarians, disputation, mendeleev,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2313 0.0300 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2100 0.0289 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2217 0.0290 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1069 0.0291 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1869 0.0290 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1698 0.0291 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1618 0.0288 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1898 0.0293 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2022 0.0291 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1717 0.0289 sec/batch
# Nearest to used: pharmaceuticals, encodes, use, vowel, atonal, derivation, amplification, unjustly,
# Nearest to known: sh, emporia, rotuma, spelled, foam, vom, ale, embark,
# Nearest to united: maintains, singapore, qatar, logs, malpractice, dudayev, needs, kearns,
# Nearest to into: exuberance, encodes, selfish, goku, daewoo, optical, upshot, emory,
# Nearest to state: rosslyn, beauties, maine, dissolution, chiropractors, disrepair, yale, cumann,
# Nearest to there: proviso, fluorescence, relating, castletown, or, zarqawi, furthermore, motionless,
# Nearest to where: laplacian, impossibility, niggle, wuhan, generalisation, unpowered, imposter, pensacola,
# Nearest to been: rebranding, make, individually, hartenstein, polyploid, cleric, empiricists, claudel,
# Nearest to http: www, edu, html, ccd, htm, hex, creasy, articles,
# Nearest to orthodox: succession, churches, cryptids, religions, baptizing, church, spurling, dogmatic,
# Nearest to consists: sulfate, attainment, clinical, statutes, scanned, congruent, attached, prevail,
# Nearest to resources: natural, trinidad, improvements, irrigated, conservation, lenders, philosophers, escalators,
# Nearest to operations: electroconvulsive, elk, forts, operational, cinematographers, requested, lingual, inflation,
# Nearest to account: appleseed, creaky, toilet, odie, apollon, vicarage, spirit, charged,
# Nearest to pope: stalinism, constantine, confessing, prelates, brotherhoods, bishops, memoirs, celebrant,
# Nearest to nobel: prize, aldous, pioneers, austrian, humanitarians, disputation, physiology, mendeleev,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1633 0.0301 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2363 0.0291 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1626 0.0291 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1638 0.0289 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1638 0.0288 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1781 0.0290 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2011 0.0291 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1662 0.0288 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1387 0.0290 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1878 0.0291 sec/batch
# Nearest to used: vowel, pharmaceuticals, atonal, amplification, use, however, saimaa, derivation,
# Nearest to known: sh, emporia, foam, rotuma, spelled, embark, lfr, vom,
# Nearest to united: maintains, qatar, singapore, logs, provisional, u, needs, dudayev,
# Nearest to into: exuberance, encodes, selfish, goku, daewoo, upshot, emory, flowered,
# Nearest to state: rosslyn, dissolution, chiropractors, yale, maine, cumann, beauties, disrepair,
# Nearest to there: relating, or, fluorescence, zarqawi, proviso, castletown, furthermore, mallorca,
# Nearest to where: laplacian, impossibility, niggle, endomorphism, imposter, nonnegative, wuhan, generalisation,
# Nearest to been: cleric, rebranding, make, polyploid, empiricists, cilicia, hartenstein, conqueror,
# Nearest to http: www, edu, html, htm, articles, website, ccd, hex,
# Nearest to orthodox: succession, churches, cryptids, baptizing, church, spurling, religions, alberta,
# Nearest to consists: attainment, sulfate, statutes, muezzin, clinical, attached, congruent, prevail,
# Nearest to resources: natural, improvements, trinidad, philosophers, conservation, irrigated, overfishing, consistently,
# Nearest to operations: electroconvulsive, elk, forts, cinematographers, operational, requested, inflation, transmitter,
# Nearest to account: appleseed, apollon, creaky, three, vicarage, spirit, virtuous, odie,
# Nearest to pope: stalinism, constantine, confessing, brotherhoods, bishops, celebrant, prelates, ros,
# Nearest to nobel: prize, pioneers, aldous, physiology, austrian, humanitarians, medicine, disputation,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2128 0.0301 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1640 0.0291 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1903 0.0290 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1815 0.0291 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1476 0.0296 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1545 0.0293 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1737 0.0293 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1251 0.0293 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2003 0.0297 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1993 0.0291 sec/batch
# Nearest to used: pharmaceuticals, vowel, use, unjustly, however, rj, saimaa, opentype,
# Nearest to known: sh, emporia, spelled, embark, rotuma, lfr, foam, oleg,
# Nearest to united: maintains, u, qatar, singapore, provisional, kearns, logs, needs,
# Nearest to into: exuberance, goku, selfish, emory, encodes, flowered, historical, explosives,
# Nearest to state: rosslyn, maine, yale, cumann, chiropractors, dissolution, alabama, resumption,
# Nearest to there: relating, proviso, mallorca, castletown, or, furthermore, fluorescence, zarqawi,
# Nearest to where: laplacian, imposter, niggle, wuhan, trouble, susa, pensacola, generalisation,
# Nearest to been: cleric, conqueror, empiricists, make, polyploid, rebranding, hartenstein, theorists,
# Nearest to http: www, edu, html, htm, hex, ccd, articles, creasy,
# Nearest to orthodox: churches, cryptids, succession, baptizing, spurling, micronesian, church, religions,
# Nearest to consists: statutes, attainment, sulfate, leeward, attached, muezzin, operates, catalysts,
# Nearest to resources: natural, improvements, conservation, trinidad, philosophers, overfishing, irrigated, fields,
# Nearest to operations: operational, electroconvulsive, forts, cinematographers, requested, elk, notional, comparable,
# Nearest to account: appleseed, three, apollon, spirit, creaky, virtuous, longman, odie,
# Nearest to pope: stalinism, constantine, ros, confessing, fruitless, brotherhoods, celebrant, bishops,
# Nearest to nobel: prize, physiology, pioneers, aldous, austrian, medicine, humanitarians, adolph,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2139 0.0300 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1267 0.0289 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1334 0.0288 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1372 0.0290 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0444 0.0289 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1332 0.0291 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1761 0.0289 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1234 0.0290 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1749 0.0061 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1202 0.0290 sec/batch
# Nearest to used: pharmaceuticals, use, vowel, names, rj, opentype, however, saimaa,
# Nearest to known: sh, emporia, foam, spelled, embark, rotuma, fry, lfr,
# Nearest to united: maintains, kearns, fought, u, logs, singapore, forestalled, states,
# Nearest to into: encodes, exuberance, upshot, goku, optical, selfish, madero, daewoo,
# Nearest to state: rosslyn, maine, yale, chiropractors, cumann, alabama, unitary, colleges,
# Nearest to there: relating, or, proviso, is, castletown, fluorescence, furthermore, zarqawi,
# Nearest to where: laplacian, niggle, nonnegative, imposter, trouble, wuhan, pensacola, generalisation,
# Nearest to been: cleric, make, conqueror, hartenstein, rebranding, individually, empiricists, pederasty,
# Nearest to http: www, edu, html, htm, articles, ccd, hex, cfm,
# Nearest to orthodox: cryptids, micronesian, baptizing, spurling, churches, succession, alberta, religions,
# Nearest to consists: statutes, attached, leeward, administrative, attainment, congruent, averages, sulfate,
# Nearest to resources: natural, improvements, philosophers, conservation, trinidad, irrigated, consistently, resource,
# Nearest to operations: forts, electroconvulsive, operational, cinematographers, requested, elk, assignment, notional,
# Nearest to account: appleseed, three, apollon, creaky, spirit, virtuous, odie, longman,
# Nearest to pope: stalinism, constantine, brotherhoods, vittoria, ros, fruitless, celebrant, confessing,
# Nearest to nobel: prize, physiology, aldous, pioneers, austrian, humanitarians, medicine, awarded,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1037 0.0301 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0808 0.0292 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0865 0.0290 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0950 0.0289 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0869 0.0290 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0583 0.0290 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0997 0.0290 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0920 0.0290 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1424 0.0291 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0343 0.0290 sec/batch
# Nearest to used: pharmaceuticals, use, however, saimaa, vowel, opentype, names, rj,
# Nearest to known: sh, emporia, foam, embark, spelled, rotuma, milky, fry,
# Nearest to united: maintains, singapore, u, logs, states, fought, forestalled, qatar,
# Nearest to into: encodes, exuberance, upshot, selfish, goku, qian, historical, scorpio,
# Nearest to state: rosslyn, yale, maine, chiropractors, unitary, cumann, alabama, arbitration,
# Nearest to there: relating, is, fluorescence, or, castletown, smaller, proviso, usbc,
# Nearest to where: laplacian, niggle, nonnegative, wuhan, pensacola, generalisation, imposter, trouble,
# Nearest to been: make, cleric, polyploid, hartenstein, conqueror, rebranding, launcher, individually,
# Nearest to http: www, edu, html, htm, articles, cfm, hex, ccd,
# Nearest to orthodox: baptizing, cryptids, micronesian, churches, succession, spurling, church, religions,
# Nearest to consists: attached, statutes, leeward, congruent, attainment, sulfate, catalysts, scanned,
# Nearest to resources: natural, philosophers, improvements, conservation, trinidad, irrigated, resource, fields,
# Nearest to operations: forts, operational, electroconvulsive, cinematographers, requested, assignment, comparable, transmitter,
# Nearest to account: appleseed, three, spirit, creaky, apollon, odie, vicarage, explains,
# Nearest to pope: constantine, bishops, stalinism, celebrant, vittoria, brotherhoods, fruitless, ros,
# Nearest to nobel: prize, physiology, aldous, humanitarians, pioneers, austrian, mendeleev, medicine,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0148 0.0301 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0565 0.0289 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0261 0.0290 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0388 0.0289 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0737 0.0289 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0789 0.0289 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0657 0.0290 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1130 0.0289 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0501 0.0292 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0445 0.0290 sec/batch
# Nearest to used: use, pharmaceuticals, however, opentype, names, vowel, rj, alloying,
# Nearest to known: sh, emporia, spelled, foam, vom, rotuma, milky, embark,
# Nearest to united: maintains, singapore, logs, forestalled, states, fought, dudayev, qatar,
# Nearest to into: encodes, exuberance, selfish, optical, upshot, historical, busoni, biochemical,
# Nearest to state: rosslyn, yale, unitary, chiropractors, maine, colleges, cumann, beauties,
# Nearest to there: relating, fluorescence, furthermore, smaller, lysenkoism, or, is, adheres,
# Nearest to where: laplacian, niggle, nonnegative, generalisation, nonempty, imposter, impossibility, pensacola,
# Nearest to been: cleric, conqueror, empiricists, polyploid, make, individually, hartenstein, begun,
# Nearest to http: www, edu, html, htm, articles, cfm, ccd, hex,
# Nearest to orthodox: churches, micronesian, baptizing, succession, spurling, cryptids, church, religions,
# Nearest to consists: attached, statutes, leeward, sulfate, scanned, passive, administrative, catalysts,
# Nearest to resources: natural, improvements, conservation, irrigated, resource, overfishing, philosophers, mangrove,
# Nearest to operations: forts, electroconvulsive, operational, requested, cinematographers, assignment, elk, bypassing,
# Nearest to account: appleseed, spirit, apollon, creaky, odie, three, hashshashin, longman,
# Nearest to pope: bishops, celebrant, constantine, stalinism, vittoria, brotherhoods, ros, confessing,
# Nearest to nobel: prize, aldous, humanitarians, austrian, physiology, pioneers, awarded, mendeleev,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0505 0.0300 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0780 0.0290 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0722 0.0290 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0429 0.0288 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0452 0.0290 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0694 0.0292 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0808 0.0290 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0696 0.0290 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0986 0.0289 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0837 0.0290 sec/batch
# Nearest to used: however, pharmaceuticals, use, rj, names, opentype, revive, vowel,
# Nearest to known: sh, emporia, spelled, rotuma, embark, foam, vom, huang,
# Nearest to united: maintains, singapore, forestalled, states, qatar, logs, dudayev, mexico,
# Nearest to into: encodes, exuberance, customs, optical, historical, victorious, madero, flowered,
# Nearest to state: rosslyn, yale, unitary, maine, cumann, chiropractors, colleges, shambles,
# Nearest to there: relating, smaller, furthermore, lysenkoism, conn, nova, or, up,
# Nearest to where: laplacian, niggle, nonnegative, generalisation, imposter, pensacola, impossibility, trouble,
# Nearest to been: cleric, conqueror, polyploid, empiricists, pederasty, make, hartenstein, begun,
# Nearest to http: www, edu, htm, html, articles, cfm, website, pictorial,
# Nearest to orthodox: churches, baptizing, micronesian, spurling, church, succession, cryptids, codices,
# Nearest to consists: leeward, attached, statutes, administrative, diputados, passive, federations, scanned,
# Nearest to resources: natural, irrigated, improvements, conservation, resource, mangrove, philosophers, overfishing,
# Nearest to operations: electroconvulsive, forts, operational, requested, cinematographers, bypassing, elk, decided,
# Nearest to account: appleseed, three, retrieve, carcinogens, explains, creaky, longman, apollon,
# Nearest to pope: bishops, celebrant, vittoria, stalinism, constantine, brotherhoods, crist, fruitless,
# Nearest to nobel: prize, aldous, physiology, pioneers, humanitarians, awarded, mendeleev, austrian,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0463 0.0300 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0210 0.0289 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0494 0.0289 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0773 0.0290 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0728 0.0290 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1241 0.0289 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1478 0.0289 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0286 0.0291 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0432 0.0288 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0488 0.0288 sec/batch
# Nearest to used: use, names, pharmaceuticals, however, rj, opentype, vowel, revive,
# Nearest to known: sh, emporia, spelled, rotuma, foam, jharkhand, oleg, embark,
# Nearest to united: maintains, states, u, singapore, forestalled, dudayev, seniority, fought,
# Nearest to into: encodes, goku, exuberance, explosives, flowered, madero, victorious, selfish,
# Nearest to state: rosslyn, yale, unitary, maine, cumann, colleges, alabama, chiropractors,
# Nearest to there: relating, smaller, lysenkoism, or, mallorca, nova, castletown, furthermore,
# Nearest to where: laplacian, nonnegative, niggle, generalisation, imposter, pensacola, susa, wuhan,
# Nearest to been: cleric, empiricists, conqueror, make, polyploid, pederasty, individually, theorists,
# Nearest to http: www, edu, htm, html, articles, cfm, ccd, pictorial,
# Nearest to orthodox: baptizing, micronesian, churches, spurling, cryptids, alberta, church, codices,
# Nearest to consists: leeward, attached, statutes, diputados, federations, administrative, congruent, scanned,
# Nearest to resources: natural, irrigated, conservation, resource, improvements, overfishing, mangrove, philosophers,
# Nearest to operations: forts, electroconvulsive, requested, operational, assignment, cinematographers, bypassing, decided,
# Nearest to account: appleseed, three, explains, hashshashin, longman, substitutionary, creaky, retrieve,
# Nearest to pope: bishops, vittoria, celebrant, constantine, lothair, brotherhoods, stalinism, ros,
# Nearest to nobel: prize, physiology, humanitarians, pioneers, aldous, awarded, medicine, mendeleev,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9975 0.0299 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0414 0.0290 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0334 0.0289 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0232 0.0289 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0765 0.0291 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0051 0.0273 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0129 0.0290 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9924 0.0291 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0255 0.0289 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9717 0.0291 sec/batch
# Nearest to used: use, pharmaceuticals, rj, revive, opentype, names, however, alloying,
# Nearest to known: sh, emporia, spelled, jharkhand, rotuma, embark, foam, oleg,
# Nearest to united: maintains, forestalled, states, singapore, u, mexico, fought, iowa,
# Nearest to into: encodes, goku, exuberance, mic, flowered, optical, of, explosives,
# Nearest to state: rosslyn, yale, maine, unitary, cumann, chiropractors, colleges, alabama,
# Nearest to there: relating, or, is, smaller, lysenkoism, adheres, nova, castletown,
# Nearest to where: niggle, laplacian, nonnegative, susa, generalisation, pensacola, imposter, wuhan,
# Nearest to been: cleric, conqueror, individually, make, srs, midwives, tempus, polyploid,
# Nearest to http: www, edu, htm, html, articles, cfm, ccd, website,
# Nearest to orthodox: micronesian, baptizing, alberta, spurling, cryptids, churches, church, codices,
# Nearest to consists: leeward, attached, statutes, administrative, diputados, federations, congruent, catalysts,
# Nearest to resources: natural, irrigated, conservation, resource, improvements, philosophers, overfishing, environment,
# Nearest to operations: forts, electroconvulsive, requested, operational, cinematographers, assignment, decided, bypassing,
# Nearest to account: appleseed, explains, three, odie, stimuli, creaky, spirit, substitutionary,
# Nearest to pope: bishops, vittoria, celebrant, ros, constantine, alphonse, stalinism, castile,
# Nearest to nobel: prize, humanitarians, physiology, aldous, pioneers, awarded, mendeleev, adolph,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9939 0.0301 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9465 0.0290 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9795 0.0291 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9992 0.0290 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0111 0.0290 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0116 0.0290 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9011 0.0290 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9710 0.0290 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9384 0.0289 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9766 0.0290 sec/batch
# Nearest to used: pharmaceuticals, use, however, names, alloying, rj, revive, opentype,
# Nearest to known: sh, emporia, rotuma, spelled, jharkhand, such, embark, milky,
# Nearest to united: maintains, states, singapore, forestalled, mexico, u, fought, logs,
# Nearest to into: encodes, to, goku, exuberance, of, mic, optical, flowered,
# Nearest to state: yale, rosslyn, unitary, maine, colleges, chiropractors, cumann, alabama,
# Nearest to there: relating, or, smaller, furthermore, is, lysenkoism, adheres, up,
# Nearest to where: laplacian, niggle, generalisation, nonnegative, susa, wuhan, pensacola, imposter,
# Nearest to been: cleric, conqueror, individually, make, midwives, renovation, seaweeds, emiliano,
# Nearest to http: www, edu, html, htm, articles, cfm, website, ccd,
# Nearest to orthodox: baptizing, churches, micronesian, spurling, church, kautsky, alberta, codices,
# Nearest to consists: leeward, attached, statutes, administrative, diputados, federations, cuboctahedron, averages,
# Nearest to resources: natural, conservation, resource, irrigated, overfishing, philosophers, improvements, environment,
# Nearest to operations: forts, electroconvulsive, requested, operational, decided, bypassing, geosynchronous, sector,
# Nearest to account: appleseed, explains, three, carcinogens, stimuli, creaky, hashshashin, substitutionary,
# Nearest to pope: bishops, celebrant, vittoria, constantine, brotherhoods, lothair, stalinism, ros,
# Nearest to nobel: prize, humanitarians, aldous, physiology, pioneers, awarded, mendeleev, adolph,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9780 0.0301 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9953 0.0291 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9494 0.0292 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0065 0.0289 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0220 0.0290 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9653 0.0290 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9721 0.0290 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9944 0.0289 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9726 0.0289 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0114 0.0290 sec/batch
# Nearest to used: pharmaceuticals, names, however, use, revive, opentype, rj, alloying,
# Nearest to known: sh, emporia, such, jharkhand, rotuma, spelled, milky, vom,
# Nearest to united: maintains, states, forestalled, mexico, singapore, u, fought, logs,
# Nearest to into: to, exuberance, encodes, of, mic, flowered, optical, kindergartens,
# Nearest to state: yale, chiropractors, unitary, rosslyn, colleges, maine, hinduism, cumann,
# Nearest to there: relating, furthermore, is, smaller, or, lysenkoism, libraries, up,
# Nearest to where: laplacian, nonnegative, niggle, generalisation, susa, imposter, pensacola, wuhan,
# Nearest to been: cleric, conqueror, individually, midwives, polyploid, quarterfinal, renovation, empiricists,
# Nearest to http: www, edu, htm, html, articles, cfm, website, ccd,
# Nearest to orthodox: baptizing, micronesian, church, spurling, alberta, churches, oriental, orthodoxy,
# Nearest to consists: leeward, attached, diputados, statutes, federations, administrative, comprises, passive,
# Nearest to resources: natural, resource, conservation, irrigated, overfishing, improvements, environment, mangrove,
# Nearest to operations: forts, electroconvulsive, requested, operational, component, approach, assignment, decided,
# Nearest to account: appleseed, explains, stimuli, three, longman, carcinogens, retrieve, substitutionary,
# Nearest to pope: celebrant, bishops, vittoria, constantine, crist, ros, stalinism, brotherhoods,
# Nearest to nobel: prize, humanitarians, aldous, physiology, pioneers, awarded, mendeleev, adolph,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0188 0.0300 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9849 0.0291 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9987 0.0289 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9849 0.0291 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0300 0.0289 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9826 0.0290 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9850 0.0290 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9519 0.0289 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9795 0.0289 sec/batch
# ...
# Nearest to into: of, to, the, various, in, and, divide, from,
# Nearest to state: hinduism, dmca, chiropractors, founded, colleges, omaha, mandriva, alabama,
# Nearest to there: are, is, someone, smaller, have, relating, many, of,
# Nearest to where: the, into, niggle, nonnegative, a, with, in, laplacian,
# Nearest to been: has, have, was, that, based, many, had, emiliano,
# Nearest to http: www, edu, htm, html, org, cfm, obscured, detailed,
# Nearest to orthodox: orthodoxy, churches, church, baptizing, spurling, alberta, feinstein, dd,
# Nearest to consists: comprises, attached, leeward, perpendicularly, diputados, branches, administrative, dyad,
# Nearest to resources: resource, natural, toshiki, fields, level, lapine, mangrove, sienkiewicz,
# Nearest to operations: forts, electroconvulsive, component, operation, army, requested, studying, staff,
# Nearest to account: accounts, carcinogens, explains, stimuli, longman, evatt, substitutionary, quotations,
# Nearest to pope: innocent, vittoria, xiii, crist, seek, stalinism, salo, ost,
# Nearest to nobel: prize, humanitarians, awarded, aldous, artes, physiology, author, pioneers,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8469 0.0303 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8409 0.0292 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8533 0.0294 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8830 0.0289 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8748 0.0288 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8728 0.0290 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8615 0.0289 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8191 0.0288 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8919 0.0289 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8874 0.0290 sec/batch
# Nearest to used: usage, however, use, term, name, referring, pharmaceuticals, names,
# Nearest to known: in, such, as, several, jharkhand, most, sh, mainly,
# Nearest to united: states, u, forestalled, citizen, maintains, mexico, americans, durango,
# Nearest to into: of, to, the, various, and, in, divide, from,
# Nearest to state: hinduism, dmca, founded, rebounding, chiropractors, omaha, colleges, bjp,
# Nearest to there: are, smaller, someone, have, relating, is, of, this,
# Nearest to where: niggle, amherst, nonnegative, into, propagation, susa, the, with,
# Nearest to been: has, that, have, was, had, many, based, emiliano,
# Nearest to http: www, edu, htm, html, org, obscured, https, cfm,
# Nearest to orthodox: orthodoxy, churches, church, baptizing, spurling, alberta, oriental, dd,
# Nearest to consists: comprises, leeward, attached, branches, diputados, administrative, perpendicularly, dyad,
# Nearest to resources: resource, natural, level, irrigated, toshiki, mangrove, arable, sienkiewicz,
# Nearest to operations: forts, operation, component, army, electroconvulsive, studying, staff, requested,
# Nearest to account: accounts, carcinogens, explains, stimuli, catastrophe, longman, charged, accumulated,
# Nearest to pope: vittoria, innocent, xiii, seek, stalinism, crist, deprive, salo,
# Nearest to nobel: prize, humanitarians, awarded, aldous, artes, physiology, pioneers, author,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8847 0.0299 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8468 0.0289 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8252 0.0289 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8177 0.0288 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8974 0.0290 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8792 0.0291 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9873 0.0290 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8945 0.0289 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9173 0.0289 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8179 0.0288 sec/batch
# Nearest to used: usage, use, however, term, referring, pharmaceuticals, names, alnico,
# Nearest to known: in, such, as, several, mainly, jharkhand, sh, allude,
# Nearest to united: states, u, citizen, forestalled, maintains, americans, omnipotence, mexico,
# Nearest to into: to, of, the, various, and, divide, from, in,
# Nearest to state: hinduism, dmca, omaha, bjp, rebounding, dipoles, founded, wealthiest,
# Nearest to there: are, relating, someone, have, smaller, is, saucer, many,
# Nearest to where: amherst, nonnegative, into, niggle, with, susa, the, perugia,
# Nearest to been: has, was, have, that, many, had, were, based,
# Nearest to http: www, edu, htm, html, org, cfm, php, detailed,
# Nearest to orthodox: orthodoxy, churches, spurling, baptizing, church, alberta, dd, feinstein,
# Nearest to consists: comprises, leeward, branches, attached, administrative, perpendicularly, diputados, dyad,
# Nearest to resources: resource, natural, arable, irrigated, level, toshiki, hydropower, fields,
# Nearest to operations: operation, army, forts, electroconvulsive, staff, studying, component, assignment,
# Nearest to account: accounts, carcinogens, explains, charged, accumulated, evatt, stimuli, longman,
# Nearest to pope: innocent, vittoria, xiii, stalinism, ost, salo, seek, deprive,
# Nearest to nobel: prize, humanitarians, awarded, artes, aldous, physiology, author, pioneers,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8251 0.0298 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8649 0.0290 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8225 0.0290 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8607 0.0290 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8210 0.0288 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8715 0.0288 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8940 0.0170 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8037 0.0289 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8436 0.0289 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8287 0.0289 sec/batch
# Nearest to used: usage, use, term, however, called, pharmaceuticals, alloying, refer,
# Nearest to known: in, such, several, as, sh, mainly, jharkhand, most,
# Nearest to united: states, u, citizen, forestalled, americans, mexico, chiropractors, durango,
# Nearest to into: the, of, various, to, divide, where, and, in,
# Nearest to state: hinduism, dmca, omaha, wealthiest, bjp, fresno, chiropractors, alabama,
# Nearest to there: are, is, someone, have, smaller, many, relating, this,
# Nearest to where: into, in, the, amherst, susa, nonnegative, perugia, niggle,
# Nearest to been: was, has, have, that, had, emiliano, were, quarterfinal,
# Nearest to http: www, edu, htm, org, html, cfm, obscured, https,
# Nearest to orthodox: orthodoxy, spurling, churches, church, baptizing, alberta, dd, feinstein,
# Nearest to consists: comprises, leeward, branches, attached, administrative, perpendicularly, diputados, dyad,
# Nearest to resources: resource, natural, irrigated, arable, toshiki, fields, hydropower, level,
# Nearest to operations: operation, forts, electroconvulsive, army, component, assignment, studying, requested,
# Nearest to account: accounts, carcinogens, explains, substitutionary, charged, quotations, longman, accumulated,
# Nearest to pope: innocent, vittoria, xiii, crist, stalinism, salo, ros, ost,
# Nearest to nobel: prize, humanitarians, awarded, artes, aldous, physiology, author, pioneers,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8236 0.0298 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8397 0.0290 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8244 0.0289 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7896 0.0288 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8383 0.0290 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8377 0.0289 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8776 0.0290 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7410 0.0289 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8129 0.0290 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8050 0.0290 sec/batch
# Nearest to used: usage, use, however, term, called, pharmaceuticals, using, alloying,
# Nearest to known: in, such, as, mainly, several, well, jharkhand, also,
# Nearest to united: states, u, mexico, forestalled, citizen, durango, maintains, americans,
# Nearest to into: of, to, the, various, in, and, from, divide,
# Nearest to state: hinduism, dmca, omaha, portion, chiropractors, colleges, bjp, hold,
# Nearest to there: are, is, have, someone, smaller, of, that, this,
# Nearest to where: the, in, into, a, with, or, nonnegative, generalisation,
# Nearest to been: has, was, have, that, had, emiliano, were, in,
# Nearest to http: www, edu, htm, org, html, cfm, obscured, faq,
# Nearest to orthodox: orthodoxy, church, spurling, churches, baptizing, alberta, feinstein, dd,
# Nearest to consists: comprises, attached, branches, leeward, administrative, perpendicularly, diputados, dyad,
# Nearest to resources: natural, resource, fields, level, hydropower, arable, irrigated, kinross,
# Nearest to operations: forts, operation, army, electroconvulsive, component, requested, brigadier, studying,
# Nearest to account: accounts, carcinogens, explains, quotations, stimuli, substitutionary, accumulated, catastrophe,
# Nearest to pope: innocent, vittoria, xiii, crist, stalinism, staircases, ost, deprive,
# Nearest to nobel: prize, humanitarians, awarded, aldous, artes, physiology, author, pioneers,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7648 0.0301 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8055 0.0289 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8412 0.0290 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8022 0.0289 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8048 0.0290 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9094 0.0291 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8374 0.0290 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8255 0.0290 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8406 0.0289 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8430 0.0290 sec/batch
# Nearest to used: usage, however, term, use, name, called, names, refer,
# Nearest to known: in, such, as, several, well, also, mainly, most,
# Nearest to united: states, u, forestalled, citizen, omnipotence, mexico, durango, americans,
# Nearest to into: to, of, the, various, in, and, divide, from,
# Nearest to state: hinduism, dmca, chiropractors, omaha, portion, ausgleich, cac, bjp,
# Nearest to there: are, have, smaller, is, someone, of, that, this,
# Nearest to where: in, the, nonnegative, into, with, a, laplacian, amherst,
# Nearest to been: have, has, was, that, were, many, had, based,
# Nearest to http: www, edu, htm, html, org, cfm, faq, detailed,
# Nearest to orthodox: orthodoxy, church, churches, oriental, spurling, baptizing, feinstein, alberta,
# Nearest to consists: comprises, branches, attached, perpendicularly, administrative, diputados, leeward, consisting,
# Nearest to resources: natural, resource, level, arable, hydropower, fields, kinross, toshiki,
# Nearest to operations: forts, operation, army, component, electroconvulsive, assignment, operational, governorate,
# Nearest to account: accounts, carcinogens, explains, quotations, stimuli, charged, longman, hypnotherapy,
# Nearest to pope: innocent, vittoria, xiii, crist, deprive, salo, stalinism, staircases,
# Nearest to nobel: prize, awarded, humanitarians, artes, aldous, physiology, author, pioneers,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8601 0.0299 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8230 0.0290 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7983 0.0290 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8274 0.0291 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8712 0.0290 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8612 0.0291 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8164 0.0289 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8461 0.0288 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8187 0.0289 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8213 0.0288 sec/batch
# Nearest to used: however, usage, use, term, called, also, name, refer,
# Nearest to known: in, as, such, several, also, mainly, well, from,
# Nearest to united: states, u, citizen, omnipotence, forestalled, americans, of, mexico,
# Nearest to into: to, of, the, various, and, in, divide, with,
# Nearest to state: hinduism, dmca, chiropractors, rebounding, bjp, omaha, colleges, portion,
# Nearest to there: are, smaller, this, is, have, someone, of, up,
# Nearest to where: with, the, in, a, nonnegative, into, or, amherst,
# Nearest to been: have, has, was, that, were, had, many, in,
# Nearest to http: www, edu, htm, html, org, obscured, cfm, faq,
# Nearest to orthodox: orthodoxy, church, churches, oriental, spurling, baptizing, feinstein, dd,
# Nearest to consists: comprises, branches, attached, leeward, administrative, perpendicularly, diputados, consisting,
# Nearest to resources: resource, natural, fields, hydropower, arable, level, irrigated, mangrove,
# Nearest to operations: operation, forts, army, component, electroconvulsive, governorate, assignment, mulberry,
# Nearest to account: accounts, carcinogens, explains, quotations, charged, stimuli, accumulated, substitutionary,
# Nearest to pope: innocent, vittoria, xiii, stalinism, crist, deprive, ost, staircases,
# Nearest to nobel: prize, awarded, humanitarians, artes, aldous, author, physiology, pioneers,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8419 0.0301 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8446 0.0292 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9335 0.0291 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8986 0.0289 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8850 0.0289 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8382 0.0291 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7818 0.0289 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8456 0.0288 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7683 0.0290 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8642 0.0290 sec/batch
# Nearest to used: usage, use, however, called, term, name, uses, refer,
# Nearest to known: in, such, as, mainly, several, also, jharkhand, from,
# Nearest to united: states, u, omnipotence, mexico, americans, citizen, forestalled, durango,
# Nearest to into: to, of, various, the, in, and, from, divide,
# Nearest to state: hinduism, omaha, dmca, southeastern, portion, fresno, rebounding, wealthiest,
# Nearest to there: are, have, is, this, of, many, smaller, someone,
# Nearest to where: in, into, the, with, nonnegative, amherst, a, niggle,
# Nearest to been: have, has, was, that, were, many, had, did,
# Nearest to http: www, edu, htm, html, org, cfm, detailed, faq,
# Nearest to orthodox: orthodoxy, church, spurling, feinstein, churches, oriental, baptizing, dd,
# Nearest to consists: comprises, branches, attached, administrative, leeward, perpendicularly, diputados, consisting,
# Nearest to resources: natural, resource, level, fields, arable, hydropower, irrigated, toshiki,
# Nearest to operations: operation, army, forts, assignment, electroconvulsive, component, governorate, brigadier,
# Nearest to account: accounts, carcinogens, explains, stimuli, quotations, accumulated, charged, longman,
# Nearest to pope: innocent, vittoria, xiii, salo, crist, stalinism, ost, deprive,
# Nearest to nobel: prize, awarded, humanitarians, physiology, author, artes, aldous, laureate,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8409 0.0299 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8018 0.0290 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
